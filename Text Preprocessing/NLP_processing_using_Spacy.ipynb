# %% [markdown]
# <a href="https://colab.research.google.com/github/yashfirkedata/NLP-Practice/blob/main/Text%20Preprocessing/NLP_processing_using_Spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Text Processing usin NLP**

# %% [markdown]
# First, you need to load the language model instance in spaCy:

# %% [markdown]
#  **en_core_web_sm** is a small English pipeline trained on written web text (blogs, news, comments), that includes vocabulary, syntax and entities.
#
# sm/md/lg refer to the sizes of the models (small, medium, large respectively).

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
nlp

# %%
introduction_doc = nlp(
    "Hello, I am Yash Firke revising Natural Language Processing!"
)

type(introduction_doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for token in introduction_doc:
  print(token.text)
# Out:
# Hello
# ,
# I
# am
# Yash
# Firke
# revising
# Natural
# Language
# Processing
# !

# %% [markdown]
# If you want to read from a file

# %%
import pathlib
file_name = "intro.txt"
introduction_doc = nlp(pathlib.Path(file_name).read_text(encoding = "utf-8"))

# %%
for token in introduction_doc:
  print(token.text)
# Out:
# Hello
# ,
# I
# am
# Yash
# Firke
# revising
# Natural
# Language
# Processing
# !

# %% [markdown]
# ## **Sentence Detection**
# Sentence detection is the process of locating where sentences start and end in a given text. This allows you to you divide a text into linguistically meaningful units.

# %%
sentences_text = (
    "Hello I am Yash Firke."
    "I am learning in the field of Ai/ML."
    "This is me practicing NLP."
    "To hire me, contact yashfirke.edu@gmail.com."
)

sentences_doc = nlp(sentences_text)

# %%
sentences = list(sentences_doc.sents)
len(sentences)
# Out:
# 2

# %%
for sentence in sentences:
    print(f"{sentence}")
    print("\n")
# Out:
# Hello I am Yash Firke.
#
#
# I am learning in the field of Ai/ML.This is me practicing NLP.To hire me, contact yashfirke.edu@gmail.com.

# %% [markdown]
# You can also slice the Span objects to produce sections of a sentence.
#
# You can also customize sentence detection behavior by using custom delimiters. Here’s an example where an ellipsis (...) is used as a delimiter, in addition to the full stop, or period (.):

# %%
ellipses_text = "The sun was setting... casting long shadows across the field... birds chirped lazily as they prepared for nightfall... the breeze carried a hint of summer... memories of childhood floated by... laughter, games, and carefree days... the world seemed to slow down... each moment stretched... every second a lifetime... nostalgia wrapped around like a warm blanket... the past and present mingling... a dance of time..."

from spacy.language import Language
@Language.component("set_custom_boundaries")

def set_custom_boundaries(doc):
  """
  Adding support to use '...' as delimiter for sentence detection
  """
  for token in doc[:-1]:
    if token.text == "...":
      doc[token.i + 1].is_sent_start = True

  return doc

# %%
custom_nlp = spacy.load("en_core_web_sm")
custom_nlp.add_pipe("set_custom_boundaries", before= "parser")
custom_ellipses_doc = custom_nlp(ellipses_text)
custom_ellipses_sentences = list(custom_ellipses_doc.sents)
len(custom_ellipses_sentences)
# Out:
# 12

# %%
for sentence in custom_ellipses_sentences:
  print(sentence)
  print("\n")
# Out:
# The sun was setting...
#
#
# casting long shadows across the field...
#
#
# birds chirped lazily as they prepared for nightfall...
#
#
# the breeze carried a hint of summer...
#
#
# memories of childhood floated by...
#
#
# laughter, games, and carefree days...
#
#
# the world seemed to slow down...
#
#
# each moment stretched...
#
#
# every second a lifetime...
#
#
# nostalgia wrapped around like a warm blanket...
#
#
# the past and present mingling...
#
#
# a dance of time...

# %% [markdown]
# ## **Tokens in spaCy**

# %% [markdown]
# *.idx attribute*

# %%
for token in sentences_doc[:10]:
  print(token, token.idx)
# Out:
# Hello 0
# I 6
# am 8
# Yash 11
# Firke 16
# . 21
# I 22
# am 24
# learning 27
# in 36

# %%
print(
    f"{'Text with Whitespace':22}"
    f"{'Is Alphanumeric?':15}"
    f"{'Is Punctuation?':18}"
    f"{'Is Stop Word?'}"
)
for token in sentences_doc[:20]:
    print(
        f"{str(token.text_with_ws):22}"
        f"{str(token.is_alpha):15}"
        f"{str(token.is_punct):18}"
        f"{str(token.is_stop)}"
    )
# Out:
# Text with Whitespace  Is Alphanumeric?Is Punctuation?   Is Stop Word?
# Hello                 True           False             False
# I                     True           False             True
# am                    True           False             True
# Yash                  True           False             False
# Firke                 True           False             False
# .                     False          True              False
# I                     True           False             True
# am                    True           False             True
# learning              True           False             False
# in                    True           False             True
# the                   True           False             True
# field                 True           False             False
# of                    True           False             True
# Ai                    True           False             False
# /                     False          True              False
# ML.This               False          False             False
# is                    True           False             True
# me                    True           False             True
# practicing            True           False             False
# NLP.To                False          False             False

# %% [markdown]
# You can even use a custom tokenizer for ex: Default parsing reads yash@gmail.com as one, you can set @ as custom infix to get 3 seperate tokens.

# %% [markdown]
# ## **Stop Words**
#
# Examples of stop words are the, are, but, and they.
#
# With NLP, stop words are generally removed because they aren’t significant, and they heavily distort any word frequency analysis.

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
len(spacy_stopwords)
# Out:
# 326

# %%
for stopword in list(spacy_stopwords)[:10]:
  print(stopword)
# Out:
# otherwise
# everywhere
# give
# besides
# she
# does
# once
# their
# anyone
# move

# %%
sentences_text = (
    "Hello I am Yash Firke."
    "I am learning in the field of Ai/ML."
    "This is me practicing NLP."
    "To hire me, contact yashfirke.edu@gmail.com."
)

sentences_doc = nlp(sentences_text)

# %% [markdown]
# You can remove stop words from the input text by making use of the .is_stop attribute of each token

# %%
for token in sentences_doc:
  if token.is_stop:
    continue

  print(token.text)
# Out:
# Hello
# Yash
# Firke
# .
# learning
# field
# Ai
# /
# ML.This
# practicing
# NLP.To
# hire
# ,
# contact
# yashfirke.edu@gmail.com
# .

# %% [markdown]
# ## **Lemmatization**
# Lemmatization is the process of reducing inflected forms of a word while still ensuring that the reduced form belongs to the language. This reduced form, or root word, is called a lemma.
#
# For example, *organizes*, *organized* and *organizing* are all forms of *organize*.
#
# It can also help you normalize the text.

# %%
sentences_text
# Out:
# 'Hello I am Yash Firke.I am learning in the field of Ai/ML.This is me practicing NLP.To hire me, contact yashfirke.edu@gmail.com.'

# %%
doc = nlp(sentences_text)
for token in doc:
  if str(token) != str(token.lemma_):
    print(f"{str(token)} : {str(token.lemma_)}")
# Out:
# Hello : hello
# am : be
# am : be
# learning : learn
# ML.This : ml.this
# is : be
# me : I
# practicing : practice
# me : I

# %% [markdown]
# You can see practicing being reduced to practice.
#
# Lemmatization helps you avoid duplicate words that may overlap conceptually.

# %% [markdown]
# ## **Word Frequency**

# %% [markdown]
# You can perform statistical analysis on it. This analysis can give you various insights, such as common words or unique words in the text

# %%
long_text = ("Data science is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data. This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results."
            "Data science is important because it combines tools, methods, and technology to generate meaning from data. Modern organizations are inundated with data; there is a proliferation of devices that can automatically collect and store information. Online systems and payment portals capture more data in the fields of e-commerce, medicine, finance, and every other aspect of human life. We have text, audio, video, and image data available in vast quantities. "
)

# %%
doc = nlp(long_text)
words = []

for token in doc:
  if token.is_stop or token.is_punct:
    continue
  words.append(token.text)

# %%
words
# Out:
# ['Data',
#  'science',
#  'study',
#  'data',
#  'extract',
#  'meaningful',
#  'insights',
#  'business',
#  'multidisciplinary',
#  'approach',
#  'combines',
#  'principles',
#  'practices',
#  'fields',
#  'mathematics',
#  'statistics',
#  'artificial',
#  'intelligence',
#  'computer',
#  'engineering',
#  'analyze',
#  'large',
#  'amounts',
#  'data',
#  'analysis',
#  'helps',
#  'data',
#  'scientists',
#  'ask',
#  'answer',
#  'questions',
#  'like',
#  'happened',
#  'happened',
#  'happen',
#  'results',
#  'Data',
#  'science',
#  'important',
#  'combines',
#  'tools',
#  'methods',
#  'technology',
#  'generate',
#  'meaning',
#  'data',
#  'Modern',
#  'organizations',
#  'inundated',
#  'data',
#  'proliferation',
#  'devices',
#  'automatically',
#  'collect',
#  'store',
#  'information',
#  'Online',
#  'systems',
#  'payment',
#  'portals',
#  'capture',
#  'data',
#  'fields',
#  'e',
#  'commerce',
#  'medicine',
#  'finance',
#  'aspect',
#  'human',
#  'life',
#  'text',
#  'audio',
#  'video',
#  'image',
#  'data',
#  'available',
#  'vast',
#  'quantities']

# %%
from collections import Counter
print(Counter(words).most_common(5))
# Out:
# [('data', 7), ('Data', 2), ('science', 2), ('combines', 2), ('fields', 2)]

# %% [markdown]
# # **Part of Speech Tagging**

# %% [markdown]
# **Part of speech or POS is a grammatical role that explains how a particular word is used in a sentence. There are typically eight parts of speech:**
#
# ```
# Noun
# Pronoun
# Adjective
# Verb
# Adverb
# Preposition
# Conjunction
# Interjection
# ```

# %%
for token in doc:
  print(f"Token: {token}")
  print(f"Token Tag: {token.tag_}")
  print(f"Token POS: {token.pos_}")
  print(f"Explaination: {spacy.explain(token.tag_)}")
  print("-"*35)
# Out:
# Token: Data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: science
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: is
# Token Tag: VBZ
# Token POS: AUX
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: the
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: study
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: of
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: to
# Token Tag: TO
# Token POS: PART
# Explaination: infinitival "to"
# -----------------------------------
# Token: extract
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: meaningful
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: insights
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: for
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: business
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------
# Token: It
# Token Tag: PRP
# Token POS: PRON
# Explaination: pronoun, personal
# -----------------------------------
# Token: is
# Token Tag: VBZ
# Token POS: AUX
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: a
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: multidisciplinary
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: approach
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: that
# Token Tag: WDT
# Token POS: PRON
# Explaination: wh-determiner
# -----------------------------------
# Token: combines
# Token Tag: VBZ
# Token POS: VERB
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: principles
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: practices
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: from
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: the
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: fields
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: of
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: mathematics
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: statistics
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: artificial
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: intelligence
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: computer
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: engineering
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: to
# Token Tag: TO
# Token POS: PART
# Explaination: infinitival "to"
# -----------------------------------
# Token: analyze
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: large
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: amounts
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: of
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------
# Token: This
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: analysis
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: helps
# Token Tag: VBZ
# Token POS: VERB
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: data
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: scientists
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: to
# Token Tag: TO
# Token POS: PART
# Explaination: infinitival "to"
# -----------------------------------
# Token: ask
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: answer
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: questions
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: like
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: what
# Token Tag: WP
# Token POS: PRON
# Explaination: wh-pronoun, personal
# -----------------------------------
# Token: happened
# Token Tag: VBD
# Token POS: VERB
# Explaination: verb, past tense
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: why
# Token Tag: WRB
# Token POS: SCONJ
# Explaination: wh-adverb
# -----------------------------------
# Token: it
# Token Tag: PRP
# Token POS: PRON
# Explaination: pronoun, personal
# -----------------------------------
# Token: happened
# Token Tag: VBD
# Token POS: VERB
# Explaination: verb, past tense
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: what
# Token Tag: WP
# Token POS: PRON
# Explaination: wh-pronoun, personal
# -----------------------------------
# Token: will
# Token Tag: MD
# Token POS: AUX
# Explaination: verb, modal auxiliary
# -----------------------------------
# Token: happen
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: what
# Token Tag: WP
# Token POS: PRON
# Explaination: wh-pronoun, personal
# -----------------------------------
# Token: can
# Token Tag: MD
# Token POS: AUX
# Explaination: verb, modal auxiliary
# -----------------------------------
# Token: be
# Token Tag: VB
# Token POS: AUX
# Explaination: verb, base form
# -----------------------------------
# Token: done
# Token Tag: VBN
# Token POS: VERB
# Explaination: verb, past participle
# -----------------------------------
# Token: with
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: the
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: results
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------
# Token: Data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: science
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: is
# Token Tag: VBZ
# Token POS: AUX
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: important
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: because
# Token Tag: IN
# Token POS: SCONJ
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: it
# Token Tag: PRP
# Token POS: PRON
# Explaination: pronoun, personal
# -----------------------------------
# Token: combines
# Token Tag: VBZ
# Token POS: VERB
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: tools
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: methods
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: technology
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: to
# Token Tag: TO
# Token POS: PART
# Explaination: infinitival "to"
# -----------------------------------
# Token: generate
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: meaning
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: from
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------
# Token: Modern
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: organizations
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: are
# Token Tag: VBP
# Token POS: AUX
# Explaination: verb, non-3rd person singular present
# -----------------------------------
# Token: inundated
# Token Tag: VBN
# Token POS: VERB
# Explaination: verb, past participle
# -----------------------------------
# Token: with
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: ;
# Token Tag: :
# Token POS: PUNCT
# Explaination: punctuation mark, colon or ellipsis
# -----------------------------------
# Token: there
# Token Tag: EX
# Token POS: PRON
# Explaination: existential there
# -----------------------------------
# Token: is
# Token Tag: VBZ
# Token POS: VERB
# Explaination: verb, 3rd person singular present
# -----------------------------------
# Token: a
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: proliferation
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: of
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: devices
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: that
# Token Tag: WDT
# Token POS: PRON
# Explaination: wh-determiner
# -----------------------------------
# Token: can
# Token Tag: MD
# Token POS: AUX
# Explaination: verb, modal auxiliary
# -----------------------------------
# Token: automatically
# Token Tag: RB
# Token POS: ADV
# Explaination: adverb
# -----------------------------------
# Token: collect
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: store
# Token Tag: VB
# Token POS: VERB
# Explaination: verb, base form
# -----------------------------------
# Token: information
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------
# Token: Online
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: systems
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: payment
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: portals
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: capture
# Token Tag: VBP
# Token POS: VERB
# Explaination: verb, non-3rd person singular present
# -----------------------------------
# Token: more
# Token Tag: JJR
# Token POS: ADJ
# Explaination: adjective, comparative
# -----------------------------------
# Token: data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: in
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: the
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: fields
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: of
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: e
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: -
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: commerce
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: medicine
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: finance
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: every
# Token Tag: DT
# Token POS: DET
# Explaination: determiner
# -----------------------------------
# Token: other
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: aspect
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: of
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: human
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: life
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------
# Token: We
# Token Tag: PRP
# Token POS: PRON
# Explaination: pronoun, personal
# -----------------------------------
# Token: have
# Token Tag: VBP
# Token POS: VERB
# Explaination: verb, non-3rd person singular present
# -----------------------------------
# Token: text
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: audio
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: video
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: ,
# Token Tag: ,
# Token POS: PUNCT
# Explaination: punctuation mark, comma
# -----------------------------------
# Token: and
# Token Tag: CC
# Token POS: CCONJ
# Explaination: conjunction, coordinating
# -----------------------------------
# Token: image
# Token Tag: NN
# Token POS: NOUN
# Explaination: noun, singular or mass
# -----------------------------------
# Token: data
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: available
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: in
# Token Tag: IN
# Token POS: ADP
# Explaination: conjunction, subordinating or preposition
# -----------------------------------
# Token: vast
# Token Tag: JJ
# Token POS: ADJ
# Explaination: adjective (English), other noun-modifier (Chinese)
# -----------------------------------
# Token: quantities
# Token Tag: NNS
# Token POS: NOUN
# Explaination: noun, plural
# -----------------------------------
# Token: .
# Token Tag: .
# Token POS: PUNCT
# Explaination: punctuation mark, sentence closer
# -----------------------------------

# %% [markdown]
# > .tag_ displays a fine-grained tag.
#
# > .pos_ displays a coarse-grained tag, which is a reduced version of the fine-grained tags.
#
# > spacy.explain() gives descriptive detials about the pos tag

# %%
# Extracting particular category of words:
nouns = []
adjectives = []
for token in doc:
  if(token.pos_ == "NOUN"):
    nouns.append(token)
  if(token.pos_ == "ADJ"):
    adjectives.append(token)

# %%
print(f"Nouns: {nouns[:5]}")
print(f"Adjectives: {adjectives[:5]}")
# Out:
# Nouns: [Data, science, study, data, insights]
# Adjectives: [meaningful, multidisciplinary, artificial, large, important]

# %% [markdown]
# ## **Visualization: Using displaCy**
# You can use displaCy to find POS tags for tokens:

# %%
from spacy import displacy
doc
# Out:
# Data science is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data. This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results.Data science is important because it combines tools, methods, and technology to generate meaning from data. Modern organizations are inundated with data; there is a proliferation of devices that can automatically collect and store information. Online systems and payment portals capture more data in the fields of e-commerce, medicine, finance, and every other aspect of human life. We have text, audio, video, and image data available in vast quantities.

# %%
displacy.serve(doc, style = "dep")
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/displacy/__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3bff579870a049aa8a16cd874f075365-0" class="displacy" width="24025" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">extract</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">meaningful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">insights</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">business.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">multidisciplinary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">approach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">combines</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">principles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">practices</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">fields</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">mathematics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">statistics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# In the image above, each token is assigned a POS tag written just below the token.

# %%
# to display inside jupyter notebook
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0a184ae1d6b74dcb949f6e251dfed30e-0" class="displacy" width="24025" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">science</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">study</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">extract</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">meaningful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">insights</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">business.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">multidisciplinary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">approach</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">combines</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">principles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">practices</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">fields</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">mathematics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">statistics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">intelligence,</tspan>
#     <tspan class="d

# %% [markdown]
# # **Preprocessing Functions**

# %% [markdown]
# Creating a preprocessor that applies following operations:
#
#
# ```
# Lowercases the text
# Lemmatizes each token
# Removes punctuation symbols
# Removes stop words
# ```

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
text = ("Data science is the study of data to extract meaningful insights for business. It is a multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, artificial intelligence, and computer engineering to analyze large amounts of data. This analysis helps data scientists to ask and answer questions like what happened, why it happened, what will happen, and what can be done with the results."
            "Data science is important because it combines tools, methods, and technology to generate meaning from data. Modern organizations are inundated with data; there is a proliferation of devices that can automatically collect and store information. Online systems and payment portals capture more data in the fields of e-commerce, medicine, finance, and every other aspect of human life. We have text, audio, video, and image data available in vast quantities. "
)

# %%
text_doc = nlp(text)

def is_token_allowed(token):
    # Check if the token is valid (not empty or just spaces)
    if not token or not str(token).strip():
        return False
    # Check if the token is a stop word or punctuation
    if token.is_stop or token.is_punct:
        return False
    # If none of the above, the token is allowed
    return True

def preprocess_token(token):
  return token.lemma_.strip().lower()

filtered_tokens = []
for token in text_doc:
    if is_token_allowed(token):
        filtered_tokens.append(preprocess_token(token))

# %%
print(filtered_tokens)
# Out:
# ['datum', 'science', 'study', 'datum', 'extract', 'meaningful', 'insight', 'business', 'multidisciplinary', 'approach', 'combine', 'principle', 'practice', 'field', 'mathematic', 'statistic', 'artificial', 'intelligence', 'computer', 'engineering', 'analyze', 'large', 'amount', 'datum', 'analysis', 'help', 'data', 'scientist', 'ask', 'answer', 'question', 'like', 'happen', 'happen', 'happen', 'result', 'datum', 'science', 'important', 'combine', 'tool', 'method', 'technology', 'generate', 'meaning', 'datum', 'modern', 'organization', 'inundate', 'datum', 'proliferation', 'device', 'automatically', 'collect', 'store', 'information', 'online', 'system', 'payment', 'portal', 'capture', 'datum', 'field', 'e', 'commerce', 'medicine', 'finance', 'aspect', 'human', 'life', 'text', 'audio', 'video', 'image', 'datum', 'available', 'vast', 'quantity']

# %% [markdown]
# ## **Rule-Based Matching Using spaCy**
# *Rule-based matching* is one of the steps in extracting information from unstructured text. It’s used to identify and extract tokens and phrases according to patterns (such as lowercase) and grammatical features (such as part of speech).

# %% [markdown]
# While you can use regular expressions to extract entities (such as phone numbers), rule-based matching in spaCy is more powerful than regex alone, because you can include semantic or grammatical filters.

# %%
mytext = (
    "Hello I am Yash Firke."
    "I am learning in the field of Ai/ML."
    "This is me practicing NLP."
    "To hire me, contact yashfirke.edu@gmail.com."
)

mydoc = nlp(mytext)

# %%
from spacy.matcher import Matcher
def extract_full_name(nlp_doc):
    # Define the pattern to match two proper nouns (first and last name)
    pattern = [{"POS": "PROPN"}, {"POS": "PROPN"}]

    # Initialize the matcher with the pattern
    matcher = Matcher(nlp_doc.vocab)
    matcher.add("FULL_NAME", [pattern])

    # Find matches in the document
    matches = matcher(nlp_doc)

    # Loop through the matches and yield the matched text
    for match_id, start, end in matches:
        span = nlp_doc[start:end]
        yield span.text

full_names = list(extract_full_name(mydoc))
full_names
# Out:
# ['Yash Firke']

# %% [markdown]
# You can do same to extract phone numbers by doing changes in pattern and
#
#
# ```
# matcher.add("PHONE_NUMBER", None, pattern)
#
# ```

# %% [markdown]
# # **Dependency Parsing Using spaCy**
# Dependency parsing is the process of extracting the dependency graph of a sentence to represent its grammatical structure. It defines the dependency relationship between headwords and their dependents. The head of a sentence has no dependency and is called the root of the sentence. The verb is usually the root of the sentence. All other words are linked to the headword.

# %% [markdown]
# The dependencies can be mapped in a directed graph representation where:
#
# - Words are the nodes.
# - Grammatical relationships are the edges.

# %% [markdown]
# Dependency parsing helps you know what role a word plays in the text and how different words relate to each other.

# %%
sample_text = "Yash is learning Natural Language Processing"
sample_doc = nlp(sample_text)

for token in sample_doc:
  print(f"Token: {token}")
  print(f"Token Tag: {token.tag_}" )
  print(f"Token Head Text: {token.head.text}" )
  print(f"Token Dependency: {token.dep_ }")
  print("-"*35)
# Out:
# Token: Yash
# Token Tag: NNP
# Token Head Text: learning
# Token Dependency: nsubj
# -----------------------------------
# Token: is
# Token Tag: VBZ
# Token Head Text: learning
# Token Dependency: aux
# -----------------------------------
# Token: learning
# Token Tag: VBG
# Token Head Text: learning
# Token Dependency: ROOT
# -----------------------------------
# Token: Natural
# Token Tag: NNP
# Token Head Text: Language
# Token Dependency: compound
# -----------------------------------
# Token: Language
# Token Tag: NNP
# Token Head Text: Processing
# Token Dependency: compound
# -----------------------------------
# Token: Processing
# Token Tag: NN
# Token Head Text: learning
# Token Dependency: dobj
# -----------------------------------

# %%
displacy.render(sample_doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b9816799c77e4c30b0d952b474c31261-0" class="displacy" width="1100" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Yash</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Natural</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Language</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Processing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9816799c77e4c30b0d952b474c31261-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9816799c77e4c30b0d952b474c31261-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9816799c77e4c30b0d952b474c31261-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9816799c77e4c30b0d952b474c31261-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9816799c77e4c30b0d952b474c31261-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9816799c77e4c30b0d952b474c31261-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9816799c77e4c30b0d952b474c31261-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9816799c77e4c30b0d952b474c31261-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b9816799c77e4c30b0d952b474c31261-0-4" stroke-width="2px" d="M420,177.0 C420,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b9816799c77e4c30b0d952b474c31261-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## **Tree and Subtree Navigation**
# The dependency graph has all the properties of a tree. This tree contains information about sentence structure and grammar and can be traversed in different ways to extract relationships.
#
# spaCy provides attributes like .children, .lefts, .rights, and .subtree to make navigating the parse tree easier.

# %% [markdown]
# ## **Shallow Parsing**
#
# Shallow parsing, or chunking, is the process of extracting phrases from unstructured text. This involves chunking groups of adjacent tokens into phrases on the basis of their POS tags. There are some standard well-known chunks such as noun phrases, verb phrases, and prepositional phrases.

# %% [markdown]
# ### Noun Phrase Detection
# A noun phrase is a phrase that has a noun as its head. It could also include other kinds of words, such as adjectives, ordinals, and determiners. Noun phrases are useful for explaining the context of the sentence. They help you understand what the sentence is about.

# %%
#  .noun_chunks on the Doc object.
for chunk in sample_doc.noun_chunks:
  print(chunk)
# Out:
# Yash
# Natural Language Processing

# %% [markdown]
# By looking at noun phrases, you can get information about your text

# %% [markdown]
# ### Verb Phrase Detection
# spaCy has no built-in functionality to extract verb phrases, so you’ll need a library called textacy. You can use pip to install textacy

# %%
# !python -m pip install textacy

# %%
import textacy

about_talk_text = (
    "The talk will introduce reader about use"
    " cases of Natural Language Processing in"
    " Fintech, making use of"
    " interesting examples along the way."
)

patterns = [{"POS": "AUX"}, {"POS": "VERB"}]
about_talk_doc = textacy.make_spacy_doc(
    about_talk_text, lang="en_core_web_sm"
)
verb_phrases = textacy.extract.token_matches(
    about_talk_doc, patterns=patterns
)

# Print all verb phrases
for chunk in verb_phrases:
    print(chunk.text)



# Extract noun phrase to explain what nouns are involved
for chunk in about_talk_doc.noun_chunks:
    print (chunk)
# Out:
# will introduce
# The talk
# reader
# use cases
# Natural Language Processing
# Fintech
# use
# interesting examples
# the way

# %% [markdown]
# ## **Named-Entity Recognition**
# Named-entity recognition (NER) is the process of locating named entities in unstructured text and then classifying them into predefined categories, such as person names, organizations, locations, monetary values, percentages, and time expressions.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

piano_class_text = (
    "Great Piano Academy is situated"
    " in Mayfair or the City of London and has"
    " world-class piano instructors."
)
piano_class_doc = nlp(piano_class_text)

for ent in piano_class_doc.ents:
    print(
        f"""
{ent.text = }
{ent.start_char = }
{ent.end_char = }
{ent.label_ = }
spacy.explain('{ent.label_}') = {spacy.explain(ent.label_)}
----------------------------------------"""
)
# Out:
# ent.text = 'Great Piano Academy'
# ent.start_char = 0
# ent.end_char = 19
# ent.label_ = 'ORG'
# spacy.explain('ORG') = Companies, agencies, institutions, etc.
# ----------------------------------------
#
# ent.text = 'Mayfair'
# ent.start_char = 35
# ent.end_char = 42
# ent.label_ = 'GPE'
# spacy.explain('GPE') = Countries, cities, states
# ----------------------------------------
#
# ent.text = 'the City of London'
# ent.start_char = 46
# ent.end_char = 64
# ent.label_ = 'GPE'
# spacy.explain('GPE') = Countries, cities, states
# ----------------------------------------

# %%
displacy.render(piano_class_doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Great Piano Academy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is situated in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mayfair
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the City of London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and has world-class piano instructors.</div></span>

# %% [markdown]
# One use case for NER is to redact people’s names from a text. For example, you might want to do this in order to hide personal information collected in a survey.
